# %%
import pandas as pd
import numpy as np
import dora as dr
from pandas.io.ga import read_ga
from pandas.io.parsers import read_table
from datetime import datetime, date, timedelta
from dora.auth import ga
from dora import auth

# %%
# Retrieve total visits by date
metrics = ["visits"]
dimensions = ["date"]

start_date = date(2012, 10, 1)
end_date = date(2013, 1, 23)

daily_visits = read_ga(metrics, dimensions=dimensions, start_date=start_date, end_date=end_date, secrets=ga.SECRETS, token_file_name=ga.TOKEN_FILE_NAME)
daily_visits = daily_visits.reset_index()

# %%
# Retrieve visits by date and pagePathLevel1
# will be in a variable called full_data
full_data = None
metrics = ['visits']
dimensions = ['date', 'pagePathLevel1']

start_date = date(2012, 10, 1)
end_date = date.today()
current_date = start_date

while current_date < end_date:
    date_string = current_date.strftime("%Y-%m-%d")
    data_section = read_ga(metrics, dimensions=dimensions, start_date=date_string, end_date=date_string, secrets=ga.SECRETS, token_file_name=ga.TOKEN_FILE_NAME)
    
    if full_data is None:
        full_data = data_section
    else:
        full_data = pd.concat([full_data, data_section])
    current_date += timedelta(days=1)
full_data = full_data.reset_index().rename(columns={"pagePathLevel1":"path"})

# %%
# Add total daily visits to the full data set
full_data = pd.merge(daily_visits, full_data, on="date")\
    .rename(columns={"visits_x":"total_visits", "visits_y":"visits"})\
    .reindex(columns=["date", "path", "visits", "total_visits"])

# %%
# Clean up the path
def strip_trailing_slash(path):
    if len(path) == 1 or path[-1] != "/":
        return path
    else:
        return path[:-1]

def strip_query_string(path):
    return path.split("?")[0]

full_data["path"] = full_data["path"].map(unicode.lower)
full_data["path"] = full_data["path"].map(strip_trailing_slash)
full_data["path"] = full_data["path"].map(strip_query_string)

# Sum up visits by date and path (because we now have some duplicates)
full_data = full_data.groupby(["date", "path"]).sum().reset_index()

# %%
# Remove any paths that have fewer than 100 visits over the entire data set
def add_visit_sum(group):
    group["total_path_visits"] = group.visits.sum()

    return group

full_data = full_data.groupby(["path"]).apply(add_visit_sum)
full_data = full_data[full_data["total_path_visits"] > 100]

del full_data["total_path_visits"]

# %%
# add proportion of visits each path accounted for each day
def add_proportion(group):
    group["visits_proportion"] = group.visits.astype(float) / group.total_visits

    return group

full_data = full_data.groupby("date").apply(add_proportion)

# %%
# Add day of week
full_data["day_of_week"] = full_data["date"].apply(lambda item: item.weekday())

# %%
# Save full_data to file
full_data.to_csv(dr.data_path("visits-by-date-path.csv"), encoding="utf-8", index=False)

# %%
# Read the data
full_data = pd.read_csv(dr.data_path("visits-by-date-path.csv"), parse_dates=[0], encoding="utf-8")

# %% [markdown]
# # Work on a single series in isolation
#
# The following cells extract a single path so that it can be worked on in isolation.
#
# Set the `path` and `column` variables to whatever you're interested in.
#
# Unless otherwise stated all moving window functions are exponentially weighted with a span of 5.

# %%
# Functions
def add_averages(frame, column, span=10):
    """
    Adds two weekly averages (averages for the same weekday over time).
        week_average:         Moving average for this weekday
        week_average_shifted: Moving average for this weekday shifted by one week (so last week's value).
    
    frame:  The DataFrame to work on
    column: The column name to add the averages for

    Returns `frame` with the two averages added.
    """
    frame = frame.reset_index()
    def grouper(group):
        group["week_average"] = pd.ewma(group[column], span=span)
        
        return group
    frame = frame.groupby("day_of_week").apply(grouper)
    frame = frame.set_index("date")
    frame["week_average_shifted"] = frame.shift(7).week_average
    frame = frame.reset_index()
    return frame

def add_standard_deviations(frame, column, span=10):
    """
    Adds three weekly standard devations.
        week_std:         Moving standard deviation for this weekday
        week_std_shifted: Moving standard deviation for this weekday shifted by one week (so last week's value)
        max_std:          Max week_std_shifted over the previous 3 days (this allows us to stabalise quicker after an event)

    frame:  The DataFrame to work on
    column: The column name to add the standard deviations for.

    Returns `frame` with the standard deviations added.
    """
    frame = frame.reset_index()
    def grouper(group):
        group["week_std"] = pd.ewmstd(group[column], span=span)
        
        return group
    frame = frame.groupby("day_of_week").apply(grouper)
    frame = frame.set_index("date")
    frame["week_std_shifted"] = frame.shift(7).week_std
    frame["max_std"] = pd.rolling_max(frame.week_std_shifted, 3)
    frame = frame.reset_index()
    return frame

def calculate_deviation(frame, column, alpha=0.4):
    """
    Calculate deviation from the mean and attempt to identify unusual records.
        deviation:            Deviation from the average for the day of the week starting from last week.
        calculated_deviation: A calculated deviation that takes into account the previous data point's deviation.
                              The intention is to consider data points less unusual if the previous point was unusual.
        z_score:              The calculated_deviation in terms of the max_std.
        is_unusual:           A flag describing whether the data point is unusual.
                              This actually contains the max column value so that it's easier to plot.
    
    frame:  The DataFrame to work on
    column: The column name to add the deviations to.
    """
    frame["deviation"] = frame[column] - frame.week_average_shifted
    frame = frame.set_index("date")
    frame["deviation_average_shifted"] = frame.shift(1).deviation
    frame = frame.reset_index()
    
    frame["calculated_deviation"] = np.abs(np.where(
             np.abs(frame.deviation - frame.deviation_average_shifted * alpha) < np.abs(frame.deviation),
             np.sign(frame.deviation) * (frame.deviation - frame.deviation_average_shifted * alpha),
             frame.deviation
             ))
    del frame["deviation_average_shifted"]
    frame["z_score"] = frame["calculated_deviation"] / frame["max_std"]
    frame["is_unusual"] = np.where(
            frame["z_score"]>3,
            frame[column].max(),
            0-frame[column].max())
    return frame

def calculate_tripple_exponential(frame, column):
    frame["tripple_exp1"] = dr.stats.tripple_exp(frame[column], 7)
    frame["tripple_exp2"] = pd.rolling_apply(frame[column], 2, dr.stats.tripple_exp2(7))
    
    return frame

def calculate_and_draw(full_data, path, column, alpha=0.65, span=10):
    single_path = full_data.set_index(["path"]).ix[path].reset_index().set_index(["date"])
    single_path.asfreq("D")
    del single_path["path"]
    single_path = single_path.reset_index()
    single_path["day_of_week"] = single_path["date"].apply(lambda item: item.weekday())

    single_path = add_averages(single_path, column, span)
    single_path = add_standard_deviations(single_path, column, span)
    single_path = calculate_deviation(single_path, column, alpha=alpha)
    single_path = calculate_tripple_exponential(single_path, column)

    # Plot that shizzle
    columns = [column, "deviation", "calculated_deviation", "max_std", "is_unusual"]
    #columns = [column, "deviation", "calculated_deviation", "max_std", "tripple_exp1", "tripple_exp2"]
    single_path.set_index("date")[columns].plot(figsize=(15, 8), title="%s - %s" % (path, column), grid=True)
    print("%s - %s" % (path, column))
    print(single_path[single_path["is_unusual"] > 0][["date", column, "deviation", "calculated_deviation", "max_std"]])
    
def autocorrelate(full_data, path, column):
    single_path = full_data.set_index("path").ix[path].reset_index().set_index("date")
    single_path.asfreq("D")
    del single_path["path"]
    pd.tools.plotting.autocorrelation_plot(single_path[column])

# %%
autocorrelate(full_data[full_data["date"]>date(2012, 11, 12)], "/change-address-driving-licence", "visits")

# %%
# Extract a single path
# Try these:
#  /apply-renew-passport
#  /jobs-jobsearch
#  /trade-tariff
#  /apply-for-business-rate-relief
#  /acas
#  /bank-holidays
#  /benefit-cap
#  /calculate-child-maintenance
#  /car-tax-disc-vehicle-licence - interresting, almost no weekly period
#  /change-photo-driving-licence
#  /change-address-driving-licence
#  /carers-allowance
#  /divorce

column = "visits"

from_november = full_data[full_data["date"] > date(2012, 11, 1)]

#calculate_and_draw(from_november, "/jobs-jobsearch", column, span=3)
#calculate_and_draw(from_november, "/trade-tariff", column)
#calculate_and_draw(from_november, "/change-address-driving-licence", column)
#calculate_and_draw(from_november, "/change-photo-driving-licence", column)
calculate_and_draw(from_november, "/divorce", column)
# Out:
# /divorce - visits
#                   date  visits    deviation  calculated_deviation     max_std
# 9  2012-11-11 00:00:00    1841   182.000000            115.050000    0.000039
# 10 2012-11-12 00:00:00    2318   291.000000            172.700000    0.000039
# 11 2012-11-13 00:00:00    1989    59.000000             59.000000    0.000039
# 12 2012-11-14 00:00:00    1918   159.000000            120.650000    0.000045
# 13 2012-11-15 00:00:00    1705   -98.000000             98.000000    0.000045
# 14 2012-11-16 00:00:00    1653   108.100000            108.100000    9.439280
# 52 2012-12-24 00:00:00     920 -1055.500287            744.822242  199.234541

# %%
single_path.to_csv(dr.data_path("%s-visits.csv" % path[1:]), encoding="utf-8", index=False)

# %% [markdown]
# # Full data experiments
#
# The following cells are experiments on the full data set. The work done on single paths in isolation is a lot better.

# %%
full_data = full_data.reset_index()
full_data.head()
# Out:
#                  date                                    path  visits  \
# 0 2012-10-01 00:00:00                                       /    3086
# 1 2012-10-01 00:00:00                      /1619-bursary-fund       0
# 2 2012-10-01 00:00:00  /about-the-export-control-organisation       0
# 3 2012-10-01 00:00:00   /accepting-returns-and-giving-refunds       1
# 4 2012-10-01 00:00:00                /access-to-learning-fund       2
#
#    total_visits  visits_proportion  day_of_week
# 0         75228           0.041022            0
# 1         25076           0.000000            0
# 2         25076           0.000000            0
# 3         50152           0.000020            0
# 4         50152           0.000040            0

# %%
def path_grouped(group):
    group = add_averages(group, "visits")
    group = add_standard_deviations(group, "visits")
    group = calculate_deviation(group, "visits", alpha=0.5)
    
    return group
full_data = full_data.groupby("path").apply(path_grouped)

# %%
full_data[full_data["path"] == "/acas"][["visits", "deviation", "calculated_deviation", "is_unusual"]].plot(figsize=(15, 8))

# %%
full_data = full_data.reset_index()
full_data[(full_data["visits"] > 100) & (full_data["is_unusual"]>0) & (full_data["date"]>date(2012, 11, 20))][:100][["path", "date", "visits", "is_unusual", "calculated_deviation"]]
# Out:
#                                                     path                date  \
# 31                                               (other) 2013-01-02 00:00:00
# 32                                               (other) 2013-01-03 00:00:00
# 33                                               (other) 2013-01-04 00:00:00
# 36                                               (other) 2013-01-07 00:00:00
# 37                                               (other) 2013-01-08 00:00:00
# 133                                                    / 2012-12-24 00:00:00
# 478                          /24_advanced_learning_loans 2013-01-07 00:00:00
# 1143                                     /access-to-work 2012-12-24 00:00:00
# 1661                           /additional-state-pension 2012-12-05 00:00:00
# 1701                           /additional-state-pension 2013-01-14 00:00:00
# 2629                                   /adoption-records 2012-11-25 00:00:00
# 2884                                      /advertise-job 2012-11-21 00:00:00
# 2885                                      /advertise-job 2012-11-22 00:00:00
# 2886                                      /advertise-job 2012-11-23 00:00:00
# 2887                                      /advertise-job 2012-11-24 00:00:00
# 15342     139         139             93.074423
# 15343     122         139             48.212788
# 15771     973        3724           2128.983707
# 17410     433        2410            791.135115
# 17867     108         108             58.959275
# 18358   77369       77369          43177.529473
# 18464     206        1388            470.143001
# 18465     146        1388            264.190429
# 20823    2438        2438           1715.914944
# 22139     232         289             88.619905
# 22279     105         438            124.732378
# 23031     298        1338            325.336805
# 23032     128        1338            269.899925
# 24358     106         467             59.090932
# 24359     126         467             64.619377
# 24366     467         467            371.442662
# 25116     684         684            552.685294
# 25389     380         500            165.000000
# 25390     324         500             96.000000
# 25541     212         733            154.232396
# 25542     202         733             97.029888
# 26759    1603        1746            898.397886
# 27117     196        2045            290.031782
# 27300     382         609            362.000000
# 27301     110         609             78.000000
# 27355     322         609            229.347031
# 27359     129         609             99.767494
# 27540     159         630            130.577891
# 27541     175         630             92.070849
# 27801     128         128             89.229596
# 28046     196        2109            450.499721
# 28102     108         167             80.805970
# 28574     291         291            125.416834
# 28887    4579      121448           1155.341157
# 28915  121448      121448         113934.207812
# 28916   28776      121448          22001.177128
# 28985     200         396            171.572978
# 28989     197         396            148.017517
# 28990     211         396             93.064029
# 28991     229         396            110.652189
# 29397     183         865            140.694030
# 29398     865         865            768.824014
# 29399     560         865            127.164680
# 29400     648         865            362.890644
# 29401     298         865             22.772537
# 29402     297         865            148.111111
# 29403     544         865            334.078616
# 29525     251        1400            646.834517
# 29637     626        6194           2944.797212
# 29638     201        6194           2213.445503
# 30055     105         308             48.939538
# 30306  110293      120727          56343.814948
# 30762     206         987            314.868672
# 31087     714        4244           1808.879377
# 31204     338         338            197.967078
# 32746    1661        9225           3333.820377
# 33518    2440       10165            704.058633
# 34021     159        2545            130.308458

# %%
# Add moving window stats by day
#full_data = full_data.set_index(["date", "path", "day_of_week"])
full_data = full_data.set_index(["date", "path", "day_of_week"])
full_data["prop_ewma"] = pd.ewma(full_data, span=4).visits_proportion
full_data["prop_ewmstd"] = pd.ewmstd(full_data, span=4).visits_proportion

full_data = full_data.reset_index()

# %%
# Add moving window stats
full_data = full_data.set_index(["date", "path"])
full_data["prop_ewma"] = pd.ewma(full_data, span=28).visits_proportion
full_data["prop_ewmstd"] = pd.ewmstd(full_data, span=28).visits_proportion

full_data = full_data.reset_index()

# %%
# Add shifted moving average
date_index = full_data.set_index(["date", "path"])
shifted = date_index.unstack().shift(7).stack()
date_index["prev_prop_ewma"] = shifted["prop_ewma"]
date_index["prev_prop_ewmstd"] = shifted["prop_ewmstd"]
full_data = date_index.reset_index()

# %%
# Identify outliers
full_data["offset"] = full_data["visits_proportion"] - full_data["prev_prop_ewma"]
full_data["abs_offset"] = np.abs(full_data["offset"])
full_data["outlier"] = full_data["abs_offset"] > (8 * full_data["prev_prop_ewmstd"])

# %%
full_data[full_data["outlier"] & (full_data["date"] > datetime(2012, 11, 1))][:100]

# %%
jobsearch = full_data[full_data["path"] == "/trade-tariff"]
jobsearch[jobsearch["date"] > datetime(2012, 11, 1)].set_index("date")[["visits", "abs_offset", "prop_ewmstd"]].plot(subplots=True)

# %%
full_data[(full_data["path"] == "/jobsearch") & (full_data["date"] > datetime(2012, 12, 1))]

# %%
pivoted["day_of_week"]

# %%
# add column for day of week
full_data["day_of_week"] = full_data["date"].apply(lambda item: item.weekday())

full_data = full_data.set_index(["date", "path"])
